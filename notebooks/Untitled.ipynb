# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../models/pruning_05/gamma0.5acc0.74dst0.32.csv')

# %%
loss = df['loss']
acc = df['test_accuracy']
density = df['density']
epochs = df['epoch']

# %%
#plt.plot(epochs, loss, c='r')
plt.plot(epochs, acc, c='b')
plt.plot(epochs, density, c='g')
plt.show()
