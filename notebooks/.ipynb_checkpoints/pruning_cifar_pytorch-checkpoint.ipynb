# %%
import torch

import torchvision
import torchvision.transforms as transforms

# %%
dev = torch.device(
    "cuda") if torch.cuda.is_available() else torch.device("cpu")

dev
# Out:
# device(type='cpu')

# %%
transform_train = transforms.Compose(
    [transforms.RandomCrop(32, padding=4),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
     # transforms Normalize ( (R_mean, G_mean, B_mean), (R_std, G_std, B_std) )
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform_test = transforms.Compose(
    [transforms.ToTensor(),
     # transforms Normalize ( (R_mean, G_mean, B_mean), (R_std, G_std, B_std) )
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 64

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)


classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]

# %%
print(trainset)

print(testset)

# %%
data = iter(trainloader)
x, y = data.next()
print(x.shape)
# Out:
# torch.Size([64, 3, 32, 32])

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.axis('Off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:7]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(7)))
# Out:
#  ship  deer   car  bird horse   dog   dog

# %%
import torch.nn as nn
import torch.nn.functional as F

class convModel(nn.Module):
    def __init__(self):
        super().__init__()
        
        # Conv2D(in_channels, out_channels, kernel_size, ...)
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 128, 3)

        self.conv4 = nn.Conv2d(128, 128, 3)
        self.conv5 = nn.Conv2d(128, 128, 3)
        
        # MaxPool2D(kernel_size, stride, ...)
        self.maxpool = nn.MaxPool2d(2, 2)

        self.dropout1 = nn.Dropout2d(0.2)
        self.dropout2 = nn.Dropout2d(0.4)

        
        self.fc1 = nn.Linear(4 * 4 * 128, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 84)
        self.fc4 = nn.Linear(84, 10)
        
    def forward(self, x):
        x = self.conv1(x)
        #x = self.maxpool(self.conv2(x))
        x = self.conv2(x)
        x = self.maxpool(self.conv3(x))
        x = F.relu(x)

        x = self.conv4(x)
        x = self.maxpool(self.conv5(x))
        x = F.relu(x)
        
        x = torch.flatten(x, 1)

        x = self.dropout2(x)
        
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)

        x = F.relu(self.fc2(x))
        x = self.dropout1(x)

        x = F.relu(self.fc3(x))
        x = self.dropout1(x)

        x = self.fc4(x)
        
        return x

# %%
def accuracy(out, yb):
    preds = torch.argmax(out, dim=1)
    return (preds == yb).float().mean()

print(len(testloader))
print(len(trainloader))
# Out:
# 157
# 782

# %%
import torch.optim as optim

#net_nopruning = convModel()

#net_p05 = convModel()
#net_p10 = convModel()
#net_p15 = convModel()

criterion = nn.CrossEntropyLoss()


lr = 0.01

#print(net_nopruning)

# %%
def density(net):
  non_zero = 0
  count = 0
  with torch.no_grad():
      for p in net.parameters():
        flatted_weights = torch.flatten(p)
        non_zero += torch.where(torch.abs(flatted_weights) != 0.0, 1, 0).sum()
        count += flatted_weights.shape[0]

  print("non zero: ", non_zero)
  print("count: ", count)
  return non_zero / count

# %%
# fit pruning
# return list of loss, acc
def fit_pruning(net, optimizer, epochs, gamma, loss_fn, train_dl, test_dl, b=8):
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []
    densities = []
    for epoch in range(epochs):  # loop over the dataset multiple times
        train_loss = 0.0
        test_loss = 0.0
        train_acc = 0.0
        test_acc = 0.0

        # TRAIN
        for i, data in enumerate(train_dl):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data[0].to(dev), data[1].to(dev)



            outputs = net(inputs)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            # >>> PRUNING <<<
            if gamma > 0.0:
                # percorrendo as camadas
                for p in net.parameters():
                    previous = p.clone().detach();
                    
                    with torch.no_grad():
                        # transformando o layer em um vetor unidimensional 
                        flatted_weights = torch.flatten(p)
    
                        # calculando o desvio padrao
                        std = torch.std(flatted_weights, -1)
    
                        # calculando o beta para a camada
                        beta = gamma * std                        
                        
                        # tensor booleano, que indica qual peso devera ser mantido
                        boolean = torch.gt(p.abs(), torch.ones_like(p) * beta)
                        
                        # multiplicando os pesos da camada pelo tensor booleano
                        p.multiply_(boolean)
                        #p[torch.logical_not(boolean)] = 0;
    
                        # >>> QUANTIZATION <<<
            
                        #qk_prime = (torch.max(torch.abs(p)) - beta) / ( 2**(b - 1) - 1 )
                        #torch.round(p/qk_prime, out=p)
                        #p.multiply_(qk_prime)
                        #C[k] = torch.round(P[k]/qk_prime) * qk_prime
    
                        #  >>> SHOW NORM DISTANCE #print(torch.norm(p - previous))
                        #p.multiply_(pruned_weights)

                        
            #print("loss: ", loss.clone().detach())
                
            train_loss += loss.item()  
            train_acc += accuracy(outputs, labels)
        
        # TEST
        for i, data in enumerate(test_dl):
            inputs, labels = data[0].to(dev), data[1].to(dev)

            with torch.no_grad():
              outputs = net(inputs)
            test_loss += loss_fn(outputs, labels).item()
            test_acc += accuracy(outputs, labels)
            
        train_loss /= 782.
        train_acc /= 782.
        test_loss /= 157.
        test_acc /= 157.
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)
        densities.append(density(net))
        
        print('Epoch: %d/%d \
               train loss: %.3f \
               train accuracy: %.3f \
               test accuracy: %.3f' %
            (epoch + 1, epochs, train_loss, train_acc, test_acc)) # 782 == total of train batches
        

    print('Finished Training')
    return train_losses, train_accuracies, test_losses, test_accuracies,densities

# %%
from statistics import mean

#net_nopruning.to(dev)
#data = fit_pruning(net_nopruning, 50, 0.0, criterion, trainloader, testloader)

#print("no pruning accuracy: %.3f" % torch.max(torch.Tensor(data[3])))
#print("no pruning density: %.5f" % density(net_nopruning))

#net_p05 = convModel()
#optimizer = optim.Adam(net_p05.parameters(), lr=0.001)
#print(net_p05)
#net_p05.to(dev)
data = fit_pruning(net_p05, optimizer, 80, 0.5, criterion, trainloader, testloader)
print("pruning gamma 0.5 accuracy: %.3f" % torch.max(torch.Tensor(data[3])))
print("pruning gamma 0.5 density: %.5f" % torch.mean(torch.Tensor(data[4])))

#net_p10.to(dev)
#data = fit_pruning(net_p10, 100, 1.0, criterion, trainloader, testloader)
#print("pruning gamma 1.0 accuracy: %.3f" % torch.max(torch.Tensor(data[3])))
#print("pruning gamma 1.0 density: %.5f" % density(net_p10))

#net_p15.to(dev)
#data = fit_pruning(net_p15, 140, 1.5, criterion, trainloader, testloader)
# non zero:  tensor(43009, device='cuda:0')
# count:  1591270
# Epoch: 63/80                train loss: 0.790                train accuracy: 0.728                test accuracy: 0.737
# non zero:  tensor(42959, device='cuda:0')
# count:  1591270
# Epoch: 64/80                train loss: 0.792                train accuracy: 0.730                test accuracy: 0.739
# non zero:  tensor(42908, device='cuda:0')
# count:  1591270
# Epoch: 65/80                train loss: 0.796                train accuracy: 0.728                test accuracy: 0.738
# non zero:  tensor(42849, device='cuda:0')
# count:  1591270
# Epoch: 66/80                train loss: 0.795                train accuracy: 0.727                test accuracy: 0.736
# non zero:  tensor(42795, device='cuda:0')
# count:  1591270
# Epoch: 67/80                train loss: 0.798                train accuracy: 0.729                test accuracy: 0.746
# non zero:  tensor(42749, device='cuda:0')
# count:  1591270
# Epoch: 68/80                train loss: 0.797                train accuracy: 0.728                test accuracy: 0.744
# non zero:  tensor(42705, device='cuda:0')
# count:  1591270
# Epoch: 69/80                train loss: 0.801                train accuracy: 0.726                test accuracy: 0.735
# non zero:  tensor(42649, device='cuda:0')
# count:  1591270
# Epoch: 70/80                train loss: 0.796                train accuracy: 0.727                test accuracy: 0.739
# non zero:  tensor(42606, device='cuda:0')
# count:  1591270
# Epoch: 71/80                train loss: 0.798                train accuracy: 0.725                test accuracy: 0.738
# non zero:  tensor(42557, device='cuda:0')
# count:  1591270
# Epoch: 72/80                train loss: 0.799                train accuracy: 0.724                test accuracy: 0.742
# non zero:  tensor(42514, device='cuda:0')
# count:  1591270
# Epoch: 73/80                train loss: 0.796                train accuracy: 0.727                test accuracy: 0.735
# non zero:  tensor(42465, device='cuda:0')
# count:  1591270
# Epoch: 74/80                train loss: 0.798                train accuracy: 0.728                test accuracy: 0.737
# non zero:  tensor(42424, device='cuda:0')
# count:  1591270
# Epoch: 75/80                train loss: 0.799                train accuracy: 0.726                test accuracy: 0.738
# non zero:  tensor(42385, device='cuda:0')
# count:  1591270
# Epoch: 76/80                train loss: 0.794                train accuracy: 0.727                test accuracy: 0.739
# non zero:  tensor(42330, device='cuda:0')
# count:  1591270
# Epoch: 77/80                train loss: 0.793                train accuracy: 0.730                test accuracy: 0.735
# non zero:  tensor(42274, device='cuda:0')
# count:  1591270
# Epoch: 78/80                train loss: 0.796                train accuracy: 0.728                test accuracy: 0.738
# non zero:  tensor(42217, device='cuda:0')
# count:  1591270
# Epoch: 79/80                train loss: 0.797                train accuracy: 0.729                test accuracy: 0.738
# non zero:  tensor(42162, device='cuda:0')
# count:  1591270
# Epoch: 80/80                train loss: 0.795                train accuracy: 0.728                test accuracy: 0.740
# Finished Training
# pruning gamma 0.5 accuracy: 0.746
# pruning gamma 0.5 density: 0.02794

# %%
#torch.save(net_nopruning, './models/no_pruning/model.pth')
print(density(net_p05))
torch.save(net_p05, './pruning_gamma05.pth')


#torch.save(net_p10, './models/pruning_gamma10/model.pth')

#torch.save(net_p15, './models/pruning_gamma15/model.pth')
# Out:
# non zero:  tensor(42162, device='cuda:0')
# count:  1591270
# tensor(0.0265, device='cuda:0')
